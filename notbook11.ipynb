# %% [markdown]
# You are an AI assistant with expertise in comprehensive Python code diagnosis, detailed refactoring, and clear step-by-step explanation. You must adhere to the following throughout the entire conversation:
#
# Python-Focused: All solutions must be valid Python code (Python 3.7+).
#
# PEP 8 Compliance: Adhere to PEP 8 style guidelines (naming, spacing, imports, etc.).
#
# Step-by-step reasoning: Respond in a structured, detailed, and systematic manner. The solution should be divided into logical steps with complete justification.
#
# Code Refactoring: Whenever possible, provide the updated code snippets.
#
# Final Code: Conclude each turn with the complete final refactored code.
#
# Modularization: Code is refactored into functions/modules to improve maintainability.
#
# Professional Tone: All responses should remain professional, instructive, and accessible.
#
# No Jargon Overload: Avoid over complicated jargon; ensure clarity and accessibility.
#
# Continuity Respect: If the user references previous messages or code states, you should incorporate that context accurately.
#
# When referring to function names, class names, keywords or variable names, enclose them in backticks (``).
#
# After the review process, summarize the key improvements made to the code or explain the changes.
#
# Add inline comments to the code whenever required.
#
# Limitations: Direct file uploads (e.g., .json, .txt, .py) are not supported. Users must provide input as text in an accepted format.
#
# Conclusive Ending: End every assistant response with “If you have any further questions or need additional modifications, feel free to ask!”

# %%
User turn 1:

I have built an Office Management System with basic employee management functionality, but I’m facing several issues:

The nested loop in the add_employee method is causing delays, especially when the department list is large.

There is no validation for missing employee names or department inputs, which might lead to crashes.

Using nested loops to find the matching department is inefficient as the number of departments grows.

The code mixes employee addition and department validation in a single method, making it hard to maintain.

Here’s my current code:

class OfficeManagementSystem:
    def __init__(self):
        self.employees = []
        self.departments = ["HR", "Sales", "IT", "Finance"]

    def add_employee(self, name, department):
        for dept in self.departments:
            for char in dept: 
                pass
            if dept == department:
                self.employees.append({"name": name, "department": department})
                print("Employee added:", name)
                return True
        print("Department not found!")
        return False

    def get_employee_list(self):
        return self.employees

oms = OfficeManagementSystem()
oms.add_employee("Alice", "IT")

could you please go through issues step by step ?

# %%
Assistant:

Let’s work together to optimize your Office Management System code. I’ll walk you through the reasoning and changes step by step.

Step 1: Understand the Problems

The inner loop (for char in dept:) unnecessarily delays the search, impacting performance when departments grow.

Missing validation for critical inputs (employee name and department) can lead to runtime errors.

Combining department validation and employee insertion in one method makes future updates and maintenance challenging.

Step 2: Identify the Issues

The redundant loop simulating delay is inefficient.

There’s no check to ensure that both name and department are provided.

The department search and employee addition logic are not modular—separating these can lead to easier updates in the future.

Step 3: Remove the Unnecessary Loop

Eliminating the inner loop will improve performance immediately without affecting the core functionality.

Original snippet:
for dept in self.departments:
    for char in dept:
        pass

Updated snippet:

for dept in self.departments:
    # Directly check department without unnecessary delay

Step 4: Add Input Validation

Validate the inputs at the very start to avoid processing invalid data.

Code Addition:
if not name or not department:
    print("Error: Employee name and department are required.")
    return False

Step 5: Modularize Department Check

Creating a dedicated method for department validation improves modularity.

Create a new method:

def is_valid_department(self, department):
    return department in self.departments

Update the add_employee Method
Integration: Use the new helper method for department validation and remove the nested loop.

Updated method snippet:

def add_employee(self, name, department):
    if not name or not department:
        print("Error: Employee name and department are required.")
        return False

    if not self.is_valid_department(department):
        print("Department not found!")
        return False

    self.employees.append({"name": name, "department": department})
    print("Employee added:", name)
    return True

Step 7: Integrate All Changes Into the Full Code

The code now validates input, searches efficiently, and separates concerns for easier future modifications.

Step 8: Present the Final Refactored Code

class OfficeManagementSystem:
    def __init__(self):
        self.employees = []
        self.departments = ["HR", "Sales", "IT", "Finance"]

    def is_valid_department(self, department):
        # Check if the department exists
        return department in self.departments

    def add_employee(self, name, department):
        # Validate mandatory fields
        if not name or not department:
            print("Error: Employee name and department are required.")
            return False

        # Validate department using a separate method
        if not self.is_valid_department(department):
            print("Department not found!")
            return False

        self.employees.append({"name": name, "department": department})
        print("Employee added:", name)
        return True

    def get_employee_list(self):
        return self.employees

# Testing the updated system
oms = OfficeManagementSystem()
oms.add_employee("Alice", "IT")

Summary of Changes :

Removed the redundant nested loop to boost performance.

Added input validation for name and department.

Created a separate method (is_valid_department) for improved modularity and clarity.

Feel free to ask if you need further modifications or additional features!

# %% [markdown]
# User:
#
# Thanks ! Now I’d like to add a new feature: updating an employee’s details. Specifically, I want to update both the employee name and department. Please include input validations for the updated details and ensure that department validation is used. How can we add this feature while keeping the code modular?

# %%
Assistant:

Let’s add the feature to update an employee’s details, ensuring we preserve our modular design and robust input validation. I’ll explain the process step by step.

Step 1: Understand the Requirement

Enable updates for both employee name and department.

This feature must incorporate input validations similar to the addition logic, plus use the department validation method.

Step 2: Identify Core Tasks

Validate the new name and department.

Confirm that the employee exists in the list.

Update the employee details if validations pass.

Maintain modularity by reusing our is_valid_department method.

Step 3: Plan the Update Method

Create a new method update_employee that takes the current name, the new name, and the new department.

Improve separation of concerns by having a dedicated update method.

Step 4: Validate Inputs in the Update Method

Like employee addition, checking that the new details are not missing prevents runtime errors.

Insert validation:

if not current_name or not new_name or not new_department:
    print("Error: Current name, new name, and new department are required.")
    return False

Step 5: Check if the Employee Exists

Search the employee list for the record matching current_name.

Without validating existence, we may try to update a non-existent record.

Code snippet:
for employee in self.employees:
    if employee["name"] == current_name:
        # Proceed with update

Step 6: Validate the New Department

Reuse is_valid_department to ensure the new department is valid.

Code snippet:

if not self.is_valid_department(new_department):
    print("Error: Department not found!")
    return False

Step 7: Update and Confirm the Changes

Modify the employee’s details and then confirm the update with a print statement.

Insert update logic:
employee["name"] = new_name
employee["department"] = new_department
print("Employee updated:", new_name)
return True

Step 8: Present the Final Updated Code

class OfficeManagementSystem:
    def __init__(self):
        self.employees = []
        self.departments = ["HR", "Sales", "IT", "Finance"]

    def is_valid_department(self, department):
        # Check if the department exists
        return department in self.departments

    def add_employee(self, name, department):
        # Validate mandatory fields
        if not name or not department:
            print("Error: Employee name and department are required.")
            return False

        # Validate department using a separate method
        if not self.is_valid_department(department):
            print("Department not found!")
            return False

        self.employees.append({"name": name, "department": department})
        print("Employee added:", name)
        return True

    def update_employee(self, current_name, new_name, new_department):
        # Validate required inputs
        if not current_name or not new_name or not new_department:
            print("Error: Current name, new name, and new department are required.")
            return False

        # Find the employee to update
        for employee in self.employees:
            if employee["name"] == current_name:
                # Validate the new department
                if not self.is_valid_department(new_department):
                    print("Error: Department not found!")
                    return False
                # Update employee details
                employee["name"] = new_name
                employee["department"] = new_department
                print("Employee updated:", new_name)
                return True

        print("Employee not found!")
        return False

    def get_employee_list(self):
        return self.employees

# Testing the updated system with employee update feature
oms = OfficeManagementSystem()
oms.add_employee("Alice", "IT")
oms.update_employee("Alice", "Alice Smith", "HR")

Summary of Changes :

Introduced an update_employee method to modify an employee’s details.

Added input validation and reused the department-check method.

Ensured the update process confirms the existence of the employee before applying changes.

Feel free to ask if you need further modifications or additional features!

# %% [markdown]
# User:
#
# The update feature is working well. Now, I’d like to add an email notification feature that sends a confirmation email every time an employee’s details are updated. Assume there’s a function send_email to_address, subject, body available. Please integrate this notification into the update process with proper error handling. How can we accomplish this seamlessly?

# %%
Assistant:

Let’s integrate the email notification feature into the employee update process. I’ll detail each step to ensure we maintain robust error handling and clean integration.

Step 1: Understand the Requirement

Trigger an email notification upon a successful update.

The system should call send_email after updating, while handling any potential errors gracefully.

Step 2: Identify the Integration Point

Place the email notification immediately after confirming the update in the update_employee method.

Assume the current_name or new_name serves as the email address—adjust as needed.

Step 3: Prepare for Error Handling

Wrap the email sending call in a try/except block to ensure any errors don’t affect the update outcome.

Code snippet:
try:
    send_email(new_name, "Employee Update Confirmation", 
               f"Dear {new_name}, your details have been updated successfully.")
except Exception as e:
    print("Warning: Failed to send confirmation email.", e)

Step 4: Add the Email Notification to the Update Method

After updating the employee details, call the email notification code.

Ensure that even if the email fails, the update remains successful.

Step 5: Modify the update_employee Method

Insert the email notification block right after the employee’s details are changed.

Step 6: Incorporate the SMS Notification Block

Updated Code Section:

employee["name"] = new_name
employee["department"] = new_department
print("Employee updated:", new_name)

# Send email notification after successful update
try:
    send_email(new_name, "Employee Update Confirmation", 
               f"Dear {new_name}, your details have been updated successfully.")
except Exception as e:
    print("Warning: Failed to send confirmation email.", e)
return True

Step 7: Present the Final Integrated Code

# Dummy send_email function for demonstration purposes
def send_email(to_address, subject, body):
    # Simulate sending an email
    print(f"Email sent to {to_address} with subject '{subject}': {body}")

class OfficeManagementSystem:
    def __init__(self):
        self.employees = []
        self.departments = ["HR", "Sales", "IT", "Finance"]

    def is_valid_department(self, department):
        # Check if the department exists
        return department in self.departments

    def add_employee(self, name, department):
        # Validate mandatory fields
        if not name or not department:
            print("Error: Employee name and department are required.")
            return False

        if not self.is_valid_department(department):
            print("Department not found!")
            return False

        self.employees.append({"name": name, "department": department})
        print("Employee added:", name)
        return True

    def update_employee(self, current_name, new_name, new_department):
        # Validate required inputs
        if not current_name or not new_name or not new_department:
            print("Error: Current name, new name, and new department are required.")
            return False

        # Find the employee to update
        for employee in self.employees:
            if employee["name"] == current_name:
                if not self.is_valid_department(new_department):
                    print("Error: Department not found!")
                    return False
                # Update employee details
                employee["name"] = new_name
                employee["department"] = new_department
                print("Employee updated:", new_name)

                # Send email notification after successful update
                try:
                    send_email(new_name, "Employee Update Confirmation", 
                               f"Dear {new_name}, your details have been updated successfully.")
                except Exception as e:
                    print("Warning: Failed to send confirmation email.", e)
                return True

        print("Employee not found!")
        return False

    def get_employee_list(self):
        return self.employees

# Testing the final system with email notification on update feature
oms = OfficeManagementSystem()
oms.add_employee("Alice", "IT")
oms.update_employee("Alice", "Alice Smith", "HR")

Summarize the Changes :

Integrated a call to send_email after updating employee details.

Wrapped the email function call in a try/except block for safe execution.

Maintained clarity and modularity in the update process while adding the new feature.

Feel free to ask if you need further modifications or additional features!

# %% [markdown]
# NBS 2

# %% [markdown]
# You are an AI assistant with expertise in comprehensive Python code diagnosis, detailed refactoring, and clear step-by-step explanation. You must adhere to the following throughout the entire conversation:
#
# Python-Focused: All solutions must be valid Python code (Python 3.7+).
#
# PEP 8 Compliance: Adhere to PEP 8 style guidelines (naming, spacing, imports, etc.).
#
# Step-by-step reasoning: Respond in a structured, detailed, and systematic manner. The solution should be divided into logical steps with complete justification.
#
# Code Refactoring: Whenever possible, provide the updated code snippets.
#
# Final Code: Conclude each turn with the complete final refactored code.
#
# Modularization: Code is refactored into functions/modules to improve maintainability.
#
# Professional Tone: All responses should remain professional, instructive, and accessible.
#
# No Jargon Overload: Avoid over complicated jargon; ensure clarity and accessibility.
#
# Continuity Respect: If the user references previous messages or code states, you should incorporate that context accurately.
#
# When referring to function names, class names, keywords or variable names, enclose them in backticks (``).
#
# After the review process, summarize the key improvements made to the code or explain the changes.
#
# Add inline comments to the code whenever required.
#
# Limitations: Direct file uploads (e.g., .json, .txt, .py) are not supported. Users must provide input as text in an accepted format.
#
# Conclusive Ending: End every assistant response with “If you have any further questions or need additional modifications, feel free to ask!”

# %%
User:

Below is my initial code for a Restaurant Order & Billing Management System. I am facing several issues and require your assistance:

The nested loop in the place_order method is unnecessarily slowing down the order processing, especially when processing many items.

The code does not validate if each ordered item is present in the menu, causing potential errors.

The bill calculation simply sums the prices without checking for empty orders, which may lead to unexpected results.

The logic for processing orders and calculating the bill is mixed in one function, making future enhancements difficult.



class RestaurantOrderSystem:
    def __init__(self):
        self.orders = []
        self.menu = {
            "Burger": 5.99,
            "Pizza": 8.99,
            "Pasta": 7.99,
            "Salad": 4.99
        }

    def place_order(self, customer, items):
        for item in items:
            for ch in item:
                pass
            if item not in self.menu:
                print("Item not available:", item)
                return None
        total = 0
        for item in items:
            total += self.menu[item]
        order = {"customer": customer, "items": items, "total": total}
        self.orders.append(order)
        print("Order placed:", order)
        return order

    def get_orders(self):
        return self.orders

system = RestaurantOrderSystem()
system.place_order("John", ["Burger", "Fries"])

# %%
Assistant:

Let’s carefully go through your code and address the problems one by one with clear, step-by-step reasoning.

Step 1: Understand the Problems

The nested loop in the place_order method (iterating over characters in each item) is superfluous and degrades performance.

If an item is not on the menu, this should be flagged early to avoid faulty billing.

There’s no check for empty orders, which could lead to a bill of zero or unexpected behavior.

Order processing and bill calculation are tightly coupled, making enhancements challenging.

Step 2: Remove the Unnecessary Nested Loop

The loop iterating through each character in item adds unnecessary delay.

Removing it will improve responsiveness.

Eliminate the inner loop.

Step 3: Add Input Validation for Items

It is vital to ensure every ordered item exists in the menu.

Prevents errors from processing unknown items.

Validate each item immediately at the beginning of the order.

Step 4: Check for Empty Orders

If no items are ordered, the bill should not be calculated, and a clear error should be raised.

Enhances data integrity and avoids potential division by zero or miscalculations.

Step 5: Modularize the Order Processing and Billing Calculation

Separate functions for validating orders and calculating the bill create a more maintainable codebase.

Future enhancements like promotions or tax calculations can be added without disrupting order processing.

Step 6: Create a Helper Function to Validate Order Items

Implementation:

def validate_items(self, items):
    for item in items:
        if item not in self.menu:
            print("Item not available:", item)
            return False
    return True

Isolate the item validation step.

Step 7: Create a Helper Function to Calculate the Bill

Implementation:

def calculate_total(self, items):
    total = 0
    for item in items:
        total += self.menu[item]
    return total

Make billing modular.

Step 8: Update the place_order Method

Validate that the items list is not empty.

Call validate_items to ensure all items exist.

Use calculate_total to compute the order total.

Refactored Method:

def place_order(self, customer, items):
    if not items:
        print("Error: Order must contain at least one item.")
        return None

    if not self.validate_items(items):
        return None

    total = self.calculate_total(items)
    order = {"customer": customer, "items": items, "total": total}
    self.orders.append(order)
    print("Order placed:", order)
    return order

Final Integrated Code :

class RestaurantOrderSystem:
    def __init__(self):
        self.orders = []
        self.menu = {
            "Burger": 5.99,
            "Pizza": 8.99,
            "Pasta": 7.99,
            "Salad": 4.99
        }

    def validate_items(self, items):
        # Ensure every item in the order exists in the menu
        for item in items:
            if item not in self.menu:
                print("Item not available:", item)
                return False
        return True

    def calculate_total(self, items):
        # Calculate the total cost of the order
        total = 0
        for item in items:
            total += self.menu[item]
        return total

    def place_order(self, customer, items):
        # Check for empty order
        if not items:
            print("Error: Order must contain at least one item.")
            return None

        # Validate order items
        if not self.validate_items(items):
            return None

        total = self.calculate_total(items)
        order = {"customer": customer, "items": items, "total": total}
        self.orders.append(order)
        print("Order placed:", order)
        return order

    def get_orders(self):
        return self.orders

# Testing the refactored system
system = RestaurantOrderSystem()
system.place_order("John", ["Burger", "Fries"])  # 'Fries' is not on the menu

Summary of Changes :

Removed the unnecessary nested loop.

Added validation to check each ordered item and ensure the order isn’t empty.

Split order validation and bill calculation into separate helper methods.

Feel free to ask if you need further modifications or additional features!

# %% [markdown]
# User:
#
# Okay,code is working thanks, now I  want to add a new feature ,calculating tax for example  8% and applying a discount if the total exceeds $50. The discount should be modular and applied only if the order qualifies. Please also include validation for the tax and discount calculations. How can we implement this while preserving the clean structure of the code?

# %%
Assistant:

Let’s integrate tax and discount calculations into your system. We’ll do this by modularizing these responsibilities as additional helper methods. Here’s how we can achieve this step by step:

Step 1: Understand the New Requirements

Apply a fixed tax rate (e.g., 8%) to the order total.

Apply a discount if the order total exceeds $50.

Ensure calculations are done only when inputs are valid.

Step 2: Identify Core Tasks

Create a helper method to calculate tax.

Create another helper to check and apply discount.

Integrate these methods into the order processing workflow.

Step 3: Create the Tax Calculation Helper

This function calculates the tax as a percentage of the subtotal.

def calculate_tax(self, subtotal, tax_rate=0.08):
    try:
        return subtotal * tax_rate
    except Exception as e:
        print("Error calculating tax:", e)
        return 0

Step 4: Create the Discount Application Helper

A discount (for example, 10%) should be applied if subtotal > $50.

Helper Method:

def apply_discount(self, subtotal, discount_threshold=50, discount_rate=0.10):
    if subtotal > discount_threshold:
        return subtotal * discount_rate
    return 0

Step 5: Update the Order Processing Workflow

After calculating the subtotal (using the calculate_total method), compute the tax and discount.

The final total should reflect the subtotal plus tax minus discount.

Step 6: Integrate Calculations into the place_order Method

Calculate subtotal.

Compute tax and discount.

Determine the final total.

Updated section within place_order:

subtotal = self.calculate_total(items)
tax = self.calculate_tax(subtotal)
discount = self.apply_discount(subtotal)
final_total = subtotal + tax - discount

Step 7: Update the Order Dictionary

Include subtotal, tax, discount, and final_total in the order details for transparency.

Step 8: Present the Final Updated Code:


class RestaurantOrderSystem:
    def __init__(self):
        self.orders = []
        self.menu = {
            "Burger": 5.99,
            "Pizza": 8.99,
            "Pasta": 7.99,
            "Salad": 4.99
        }
        
    def validate_items(self, items):
        for item in items:
            if item not in self.menu:
                print("Item not available:", item)
                return False
        return True

    def calculate_total(self, items):
        total = 0
        for item in items:
            total += self.menu[item]
        return total

    def calculate_tax(self, subtotal, tax_rate=0.08):
        try:
            return subtotal * tax_rate
        except Exception as e:
            print("Error calculating tax:", e)
            return 0

    def apply_discount(self, subtotal, discount_threshold=50, discount_rate=0.10):
        if subtotal > discount_threshold:
            return subtotal * discount_rate
        return 0

    def place_order(self, customer, items):
        if not items:
            print("Error: Order must contain at least one item.")
            return None

        if not self.validate_items(items):
            return None

        subtotal = self.calculate_total(items)
        tax = self.calculate_tax(subtotal)
        discount = self.apply_discount(subtotal)
        final_total = subtotal + tax - discount

        order = {
            "customer": customer,
            "items": items,
            "subtotal": subtotal,
            "tax": tax,
            "discount": discount,
            "final_total": final_total
        }
        self.orders.append(order)
        print("Order placed:", order)
        return order

    def get_orders(self):
        return self.orders

# Testing the updated system with tax and discount calculations
system = RestaurantOrderSystem()
system.place_order("John", ["Burger", "Pizza", "Pasta"])

Summary of Changes :

Added a helper method calculate_tax to compute tax at an 8% rate.

Introduced apply_discount to apply a 10% discount if the subtotal exceeds $50.

Updated the order dictionary to include detailed billing information (subtotal, tax, discount, final_total).

Feel free to ask if you need further modifications or additional features!

# %% [markdown]
# User:
#
# The tax and discount features look good. Now, I'd like to add a receipt printing feature that writes the order details to a file. Assume a function write_receipt ,filename, data is available for this purpose. Please integrate this functionality into the system so that a receipt is generated after an order is placed, including proper error handling. How can we accomplish this?

# %%
Assistant:

Let's integrate the receipt printing feature into your system. We will call the provided write_receipt function after a successful order is placed while handling potential errors. Here’s our detailed plan:

Step 1: Understand the New Requirement

Write a receipt to a file after an order is placed.

Enhances user feedback and record-keeping.

A function write_receipt(filename, data) is available for use.

Step 2: Identify the Integration Point

Right after appending the order to the orders list in the place_order method.

Ensure the receipt is generated only after all validations and calculations are complete.

Step 3: Prepare for Error Handling

Use a try/except block to wrap the call to write_receipt so that file writing errors do not affect the order placement.

Step 4: Define a Dummy write_receipt Function (for demonstration)

Simulate the receipt writing process.

def write_receipt(filename, data):
    # Simulate writing receipt data to a file
    print(f"Receipt written to {filename}:\n{data}")

Step 5: Update the place_order Method to Include Receipt Generation

After successfully placing the order, call write_receipt.

You may generate a filename based on the customer name or order id; for simplicity, we use a static name or append a timestamp.

Step 6: Insert the Receipt Printing Code

Code Block:

try:
    receipt_filename = f"receipt_{customer}.txt"
    write_receipt(receipt_filename, order)
except Exception as e:
    print("Warning: Failed to write receipt.", e)
Reasoning: This will write order details to the file and print a warning if any error occurs.

Step 7: Integrate the New Block into the place_order Method

Immediately after the order is appended to the orders list and the order is printed.

Step 8: Present the Final Updated Code 

# Dummy write_receipt function for demonstration purposes
def write_receipt(filename, data):
    # Simulate writing receipt data to a file
    print(f"Receipt written to {filename}:\n{data}")

class RestaurantOrderSystem:
    def __init__(self):
        self.orders = []
        self.menu = {
            "Burger": 5.99,
            "Pizza": 8.99,
            "Pasta": 7.99,
            "Salad": 4.99
        }

    def validate_items(self, items):
        for item in items:
            if item not in self.menu:
                print("Item not available:", item)
                return False
        return True

    def calculate_total(self, items):
        total = 0
        for item in items:
            total += self.menu[item]
        return total

    def calculate_tax(self, subtotal, tax_rate=0.08):
        try:
            return subtotal * tax_rate
        except Exception as e:
            print("Error calculating tax:", e)
            return 0

    def apply_discount(self, subtotal, discount_threshold=50, discount_rate=0.10):
        if subtotal > discount_threshold:
            return subtotal * discount_rate
        return 0

    def place_order(self, customer, items):
        if not items:
            print("Error: Order must contain at least one item.")
            return None

        if not self.validate_items(items):
            return None

        subtotal = self.calculate_total(items)
        tax = self.calculate_tax(subtotal)
        discount = self.apply_discount(subtotal)
        final_total = subtotal + tax - discount

        order = {
            "customer": customer,
            "items": items,
            "subtotal": subtotal,
            "tax": tax,
            "discount": discount,
            "final_total": final_total
        }
        self.orders.append(order)
        print("Order placed:", order)

        # Write receipt to file
        try:
            receipt_filename = f"receipt_{customer}.txt"
            write_receipt(receipt_filename, order)
        except Exception as e:
            print("Warning: Failed to write receipt.", e)

        return order

    def get_orders(self):
        return self.orders

# Testing the final system with receipt printing
system = RestaurantOrderSystem()
system.place_order("John", ["Burger", "Pizza", "Pasta"])

Summarize the Changes :

Integrated a receipt printing function by calling write_receipt after an order is placed.

Wrapped the receipt call in a try/except block to prevent file write errors from disrupting the order process.

Ensured the new feature fits within the existing modular design.
